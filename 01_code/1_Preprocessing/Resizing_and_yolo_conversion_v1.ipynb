# %%
# !pip install fiftyone
# ! pip install requests pycocotools pillow

# %%
# import fiftyone as fo
# import fiftyone.zoo as foz

import cv2
from PIL import Image, ImageDraw
import pandas as pd
import os
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import numpy as np
import random
import skimage.io as io

import torch
from torchvision import transforms
import torch.nn as nn
import torch.optim as optim

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

import os
from torch.utils.data import Dataset, DataLoader, ConcatDataset
from pycocotools.coco import COCO
import torchvision.transforms as T

import torchvision.transforms as transforms
from torchsummary import summary

import math
import json
from tqdm import tqdm


from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
import nltk
nltk.download('punkt')

import requests
from io import BytesIO
# Out:
# [nltk_data] Downloading package punkt to /Users/ninageyer/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
# set the device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cpu

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Load and visualize Oxford Town

# %%
oxford_annotations = pd.read_csv('Oxford/TownCentre-groundtruth.top', names= ['personNumber', 'frameNumber',
                                'headNumber', 'bodyNumber', 'headLeft', 'headTop', 'headRight', 'headBottom', 'bodyLeft', 'bodyTop', 'bodyRight', 'bodyBottom'])
oxford_annotations.head(5)
# Out:
#    personNumber  frameNumber  headNumber  bodyNumber  headLeft  headTop  \
# 0             0            0           1           1   270.828  794.098
# 1             1            0           1           1   308.304  302.982
# 2             2            0           1           1   307.919  241.003
# 3             3            0           1           1   739.951  231.693
# 4             4            0           1           1   814.375  246.562
#
#    headRight  headBottom  bodyLeft  bodyTop  bodyRight  bodyBottom
# 0    309.037     834.066   235.925  770.142    371.546    1101.029
# 1    330.837     326.823   285.748  291.418    370.556     493.414
# 2    328.645     262.841   286.849  230.501    365.794     416.410
# 3    759.968     253.491   719.708  220.830    786.893     408.145
# 4    835.021     268.946   793.722  235.410    861.430     427.627

# %%
output_dir = 'Oxford/Images'

# Function to draw bounding boxes on an image
def draw_bounding_boxes(image, boxes):
    for box in boxes:
        x1 = int(box[0])
        y1 = int(box[1])
        x2 = int(box[2])
        y2 = int(box[3])
        cv2.rectangle(image, (x1, y1), (x2, y2), (255, 0, 0), 2)  # Blue color bounding box
    return image

# Visualize images with bounding boxes
frames = oxford_annotations['frameNumber'].unique()
frames10 = frames[2995:2996]
for frame in frames10:
    frame = int(frame)
    image_path = os.path.join(output_dir, f'{frame}.jpg')
    image = cv2.imread(image_path)

    if image is not None:
        # Extract bounding box coordinates for the current frame
        boxes = oxford_annotations[oxford_annotations['frameNumber'] == frame][['bodyLeft', 'bodyTop', 'bodyRight', 'bodyBottom']].values

        # Draw bounding boxes on the image
        image_with_boxes = draw_bounding_boxes(image, boxes)

        # Convert BGR image to RGB for matplotlib
        image_rgb = cv2.cvtColor(image_with_boxes, cv2.COLOR_BGR2RGB)

        # Display the image with bounding boxes
        plt.figure(figsize=(10, 10))
        plt.imshow(image_rgb)
        plt.title(f'Frame {frame}')
        plt.axis('off')
        plt.show()
    else:
        print(f"Image for frame {frame} not found.")

# %% [markdown]
# ### Load and visualize COCO

# %%
# Paths to annotation files
coco_train_inst_ann_file = "/content/drive/MyDrive/COCO_dataset/train/raw/instances_train2017.json"

# Visualize example image
coco = COCO(coco_train_inst_ann_file)
catIds = coco.getCatIds(catNms='person')
imgIds = coco.getImgIds(catIds=catIds)

# Filter images with at least one bounding box annotation
filtered_imgIds = []
for img_id in imgIds:
    annIds = coco.getAnnIds(imgIds=img_id, iscrowd=None)
    anns = coco.loadAnns(annIds)
    if any(ann['bbox'] for ann in anns):
        filtered_imgIds.append(img_id)

# Initialize random image
random_img_id = random.choice(filtered_imgIds)

# Initialize random image
img = coco.loadImgs(random_img_id)[0]

# Load the image
I = io.imread(img['coco_url'])

fig, ax = plt.subplots()
ax.imshow(I)

annIds = coco.getAnnIds(imgIds=img['id'], iscrowd=None, catIds=catIds[0])
anns = coco.loadAnns(annIds)

for ann in anns:
    box = ann['bbox']
    bb = patches.Rectangle((box[0], box[1]), box[2], box[3], linewidth=2, edgecolor="blue", facecolor="none")
    ax.add_patch(bb)

plt.axis('off')
plt.show()
# Out:
# loading annotations into memory...
# Done (t=30.80s)
# creating index...
# index created!

# %% [markdown]
# ### Resize oxford images and convert to yolo format

# %%
import os
from PIL import Image
import pandas as pd

def resize_with_padding(image, target_size):
    original_size = image.size
    aspect_ratio = original_size[0] / original_size[1]

    if aspect_ratio > 1:
        new_width = target_size
        new_height = int(target_size / aspect_ratio)
    else:
        new_height = target_size
        new_width = int(target_size * aspect_ratio)

    image = image.resize((new_width, new_height), Image.LANCZOS)

    new_image = Image.new("RGB", (target_size, target_size), (0, 0, 0))
    new_image.paste(image, ((target_size - new_width) // 2, (target_size - new_height) // 2))

    padding_x = (target_size - new_width) // 2
    padding_y = (target_size - new_height) // 2

    return new_image, original_size, padding_x, padding_y, new_width, new_height

def clip_bounding_box(box, padding_x, padding_y, new_width, new_height):
    xmin = max(box[0] + padding_x, padding_x)
    ymin = max(box[1] + padding_y, padding_y)
    xmax = min(box[2] + padding_x, padding_x + new_width)
    ymax = min(box[3] + padding_y, padding_y + new_height)

    xmin = min(xmin, xmax)
    ymin = min(ymin, ymax)

    return (xmin, ymin, xmax, ymax)

def get_bounding_boxes_for_frame(df, frame_number):
    frame_data = df[df['frameNumber'] == frame_number]
    bounding_boxes = []
    for _, row in frame_data.iterrows():
        box = (row['bodyLeft'], row['bodyTop'], row['bodyRight'], row['bodyBottom'])
        bounding_boxes.append(box)
    return bounding_boxes

def convert_bbox_to_yolo(box, image_width, image_height):
    x_center = (box[0] + box[2]) / 2.0 / image_width
    y_center = (box[1] + box[3]) / 2.0 / image_height
    width = (box[2] - box[0]) / image_width
    height = (box[3] - box[1]) / image_height
    return f"0 {x_center:.6f} {y_center:.6f} {width:.6f} {height:.6f}"

def resize_and_save_all_images(image_dir, df, target_dir, target_size, target_annotation_dir, max_frame_number=3090):
    if not os.path.exists(target_dir):
        os.makedirs(target_dir)
    if not os.path.exists(target_annotation_dir):
        os.makedirs(target_annotation_dir)

    # Get and sort image filenames numerically
    img_filenames = sorted(os.listdir(image_dir), key=lambda x: int(os.path.splitext(x)[0]))

    total_images_processed = 0  # Counter for processed images

    for img_filename in img_filenames:
        try:
            # Extract frame number from the filename
            frame_number = int(os.path.splitext(img_filename)[0])
            if frame_number > max_frame_number:
                break  # Stop processing if frame number exceeds max_frame_number

            img_path = os.path.join(image_dir, img_filename)
            target_path = os.path.join(target_dir, img_filename)
            annotation_file = os.path.join(target_annotation_dir, os.path.splitext(img_filename)[0] + '.txt')

            # Open image
            image = Image.open(img_path)

            # Get bounding boxes for the current frame
            bounding_boxes = get_bounding_boxes_for_frame(df, frame_number)

            # Resize image and bounding boxes
            resized_image, original_size, padding_x, padding_y, new_width, new_height = resize_with_padding(image, target_size)

            # Scale and clip bounding boxes to match the resized image
            scale_x = new_width / original_size[0]
            scale_y = new_height / original_size[1]

            resized_bounding_boxes = [
                clip_bounding_box(
                    (
                        int(box[0] * scale_x),
                        int(box[1] * scale_y),
                        int(box[2] * scale_x),
                        int(box[3] * scale_y)
                    ),
                    padding_x, padding_y, new_width, new_height
                )
                for box in bounding_boxes
            ]

            # Save the resized image
            resized_image.save(target_path)
            print(f"Resized and saved {img_filename}")

            yolo_annotations = [
                convert_bbox_to_yolo(box, target_size, target_size)
                for box in resized_bounding_boxes
            ]

            with open(annotation_file, 'w') as f:
                for annotation in yolo_annotations:
                    f.write(annotation + '\n')
            print(f"{img_filename} converted to YOLO format")

            total_images_processed += 1  # Increment the counter

        except Exception as e:
            print(f"Error processing {img_filename}: {e}")

    print(f"Total number of successfully resized and converted images: {total_images_processed}")

# Load the Oxford annotations
oxford_annotations = pd.read_csv('Oxford/TownCentre-groundtruth.top', names=[
    'personNumber', 'frameNumber', 'headNumber', 'bodyNumber',
    'headLeft', 'headTop', 'headRight', 'headBottom',
    'bodyLeft', 'bodyTop', 'bodyRight', 'bodyBottom'
])

source_dir = 'Oxford/Images'
target_dir = 'Oxford/Images_resized'
target_ann_dir = 'Oxford/Yolo_annotations'
target_size = 128

# Resize and save images up to and including frame 3090
resize_and_save_all_images(source_dir, oxford_annotations, target_dir, target_size, target_ann_dir, max_frame_number=3090)
# Out:
# Resized and saved 0.jpg
# 0.jpg converted to YOLO format
# Resized and saved 1.jpg
# 1.jpg converted to YOLO format
# Resized and saved 2.jpg
# 2.jpg converted to YOLO format
# Resized and saved 3.jpg
# 3.jpg converted to YOLO format
# Resized and saved 4.jpg
# 4.jpg converted to YOLO format
# Resized and saved 5.jpg
# 5.jpg converted to YOLO format
# Resized and saved 6.jpg
# 6.jpg converted to YOLO format
# Resized and saved 7.jpg
# 7.jpg converted to YOLO format
# Resized and saved 8.jpg
# 8.jpg converted to YOLO format
# Resized and saved 9.jpg
# 9.jpg converted to YOLO format
# Resized and saved 10.jpg
# 10.jpg converted to YOLO format
# Resized and saved 11.jpg
# 11.jpg converted to YOLO format
# Resized and saved 12.jpg
# 12.jpg converted to YOLO format
# Resized and saved 13.jpg
# 13.jpg converted to YOLO format
# Resized and saved 14.jpg
# 14.jpg converted to YOLO format
# Resized and saved 15.jpg
# 15.jpg converted to YOLO format
# Resized and saved 16.jpg
# 16.jpg converted to YOLO format
# Resized and saved 17.jpg
# 17.jpg converted to YOLO format
# Resized and saved 18.jpg
# 18.jpg converted to YOLO format
# Resized and saved 19.jpg
# 19.jpg converted to YOLO format
# Resized and saved 20.jpg
# 20.jpg converted to YOLO format
# Resized and saved 21.jpg
# 21.jpg converted to YOLO format
# Resized and saved 22.jpg
# 22.jpg converted to YOLO format
# Resized and saved 23.jpg
# 23.jpg converted to YOLO format
# Resized and saved 24.jpg
# 24.jpg converted to YOLO format
# Resized and saved 25.jpg
# 25.jpg converted to YOLO format
# Resized and saved 26.jpg
# 26.jpg converted to YOLO format
# Resized and saved 27.jpg
# 27.jpg converted to YOLO format
# Resized and saved 28.jpg
# 28.jpg converted to YOLO format
# Resized and saved 29.jpg
# 29.jpg converted to YOLO format
# Resized and saved 30.jpg
# 30.jpg converted to YOLO format
# Resized and saved 31.jpg
# 31.jpg converted to YOLO format
# Resized and saved 32.jpg
# 32.jpg converted to YOLO format
# Resized and saved 33.jpg
# 33.jpg converted to YOLO format
# Resized and saved 34.jpg
# 34.jpg converted to YOLO format
# Resized and saved 35.jpg
# 35.jpg converted to YOLO format
# Resized and saved 36.jpg
# 36.jpg converted to YOLO format
# Resized and saved 37.jpg
# 37.jpg converted to YOLO format
# Resized and saved 38.jpg
# 38.jpg converted to YOLO format
# Resized and saved 39.jpg
# 39.jpg converted to YOLO format
# Resized and saved 40.jpg
# 40.jpg converted to YOLO format
# Resized and saved 41.jpg
# 41.jpg converted to YOLO format
# Resized and saved 42.jpg
# 42.jpg converted to YOLO format
# Resized and saved 43.jpg
# 43.jpg converted to YOLO format
# Resized and saved 44.jpg
# 44.jpg converted to YOLO format
# Resized and saved 45.jpg
# 45.jpg converted to YOLO format
# Resized and saved 46.jpg
# 46.jpg converted to YOLO format
# Resized and saved 47.jpg
# 47.jpg converted to YOLO format
# Resized and saved 48.jpg
# 48.jpg converted to YOLO format
# Resized and saved 49.jpg
# 49.jpg converted to YOLO format
# Resized and saved 50.jpg
# 50.jpg converted to YOLO format
# Resized and saved 51.jpg
# 51.jpg converted to YOLO format
# Resized and saved 52.jpg
# 52.jpg converted to YOLO format
# Resized and saved 53.jpg
# 53.jpg converted to YOLO format
# Resized and saved 54.jpg
# 54.jpg converted to YOLO format
# Resized and saved 55.jpg
# 55.jpg converted to YOLO format
# Resized and saved 56.jpg
# 56.jpg converted to YOLO format
# Resized and saved 57.jpg
# 57.jpg converted to YOLO format
# Resized and saved 58.jpg
# 58.jpg converted to YOLO format
# Resized and saved 59.jpg
# 59.jpg converted to YOLO format
# Resized and saved 60.jpg
# 60.jpg converted to YOLO format
# Resized and saved 61.jpg
# 61.jpg converted to YOLO format
# Resized and saved 62.jpg
# 62.jpg converted to YOLO format
# Resized and saved 63.jpg
# 63.jpg converted to YOLO format
# Resized and saved 64.jpg
# 64.jpg converted to YOLO format
# Resized and saved 65.jpg
# 65.jpg converted to YOLO format
# Resized and saved 66.jpg
# 66.jpg converted to YOLO format
# Resized and saved 67.jpg
# 67.jpg converted to YOLO format
# Resized and saved 68.jpg
# 68.jpg converted to YOLO format
# Resized and saved 69.jpg
# 69.jpg converted to YOLO format
# Resized and saved 70.jpg
# 70.jpg converted to YOLO format
# Resized and saved 71.jpg
# 71.jpg converted to YOLO format
# Resized and saved 72.jpg
# 72.jpg converted to YOLO format
# Resized and saved 73.jpg
# 73.jpg converted to YOLO format
# Resized and saved 74.jpg
# 74.jpg converted to YOLO format
# Resized and saved 75.jpg
# 75.jpg converted to YOLO format
# Resized and saved 76.jpg
# 76.jpg converted to YOLO format
# Resized and saved 77.jpg
# 77.jpg converted to YOLO format
# Resized and saved 78.jpg
# 78.jpg converted to YOLO format
# Resized and saved 79.jpg
# 79.jpg converted to YOLO format
# Resized and saved 80.jpg
# 80.jpg converted to YOLO format
# Resized and saved 81.jpg
# 81.jpg converted to YOLO format
# Resized and saved 82.jpg
# 82.jpg converted to YOLO format
# Resized and saved 83.jpg
# 83.jpg converted to YOLO format
# Resized and saved 84.jpg
# 84.jpg converted to YOLO format
# Resized and saved 85.jpg
# 85.jpg converted to YOLO format
# Resized and saved 86.jpg
# 86.jpg converted to YOLO format
# Resized and saved 87.jpg
# 87.jpg converted to YOLO format
# Resized and saved 88.jpg
# 88.jpg converted to YOLO format
# Resized and saved 89.jpg
# 89.jpg converted to YOLO format
# Resized and saved 90.jpg
# 90.jpg converted to YOLO format
# Resized and saved 91.jpg
# 91.jpg converted to YOLO format
# Resized and saved 92.jpg
# 92.jpg converted to YOLO format
# Resized and saved 93.jpg
# 93.jpg converted to YOLO format
# Resized and saved 94.jpg
# 94.jpg converted to YOLO format
# Resized and saved 95.jpg
# 95.jpg converted to YOLO format
# Resized and saved 96.jpg
# 96.jpg converted to YOLO format
# Resized and saved 97.jpg
# 97.jpg converted to YOLO format
# Resized and saved 98.jpg
# 98.jpg converted to YOLO format
# Resized and saved 99.jpg
# 99.jpg converted to YOLO format
# Resized and saved 100.jpg
# 100.jpg converted to YOLO format
# Resized and saved 101.jpg
# 101.jpg converted to YOLO format
# Resized and saved 102.jpg
# 102.jpg converted to YOLO format
# Resized and saved 103.jpg
# 103.jpg converted to YOLO format
# Resized and saved 104.jpg
# 104.jpg converted to YOLO format
# Resized and saved 105.jpg
# 105.jpg converted to YOLO format
# Resized and saved 106.jpg
# 106.jpg converted to YOLO format
# Resized and saved 107.jpg
# 107.jpg converted to YOLO format
# Resized and saved 108.jpg
# 108.jpg converted to YOLO format
# Resized and saved 109.jpg
# 109.jpg converted to YOLO format
# Resized and saved 110.jpg
# 110.jpg converted to YOLO format
# Resized and saved 111.jpg
# 111.jpg converted to YOLO format
# Resized and saved 112.jpg
# 112.jpg converted to YOLO format
# Resized and saved 113.jpg
# 113.jpg converted to YOLO format
# Resized and saved 114.jpg
# 114.jpg converted to YOLO format
# Resized and saved 115.jpg
# 115.jpg converted to YOLO format
# Resized and saved 116.jpg
# 116.jpg converted to YOLO format
# Resized and saved 117.jpg
# 117.jpg converted to YOLO format
# Resized and saved 118.jpg
# 118.jpg converted to YOLO format
# Resized and saved 119.jpg
# 119.jpg converted to YOLO format
# Resized and saved 120.jpg
# 120.jpg converted to YOLO format
# Resized and saved 121.jpg
# 121.jpg converted to YOLO format
# Resized and saved 122.jpg
# 122.jpg converted to YOLO format
# Resized and saved 123.jpg
# 123.jpg converted to YOLO format
# Resized and saved 124.jpg
# 124.jpg converted to YOLO format
# Resized and saved 125.jpg
# 125.jpg converted to YOLO format
# Resized and saved 126.jpg
# 126.jpg converted to YOLO format
# Resized and saved 127.jpg
# 127.jpg converted to YOLO format
# Resized and saved 128.jpg
# 128.jpg converted to YOLO format
# Resized and saved 129.jpg
# 129.jpg converted to YOLO format
# Resized and saved 130.jpg
# 130.jpg converted to YOLO format
# Resized and saved 131.jpg
# 131.jpg converted to YOLO format
# Resized and saved 132.jpg
# 132.jpg converted to YOLO format
# Resized and saved 133.jpg
# 133.jpg converted to YOLO format
# Resized and saved 134.jpg
# 134.jpg converted to YOLO format
# Resized and saved 135.jpg
# 135.jpg converted to YOLO format
# Resized and saved 136.jpg
# 136.jpg converted to YOLO format
# Resized and saved 137.jpg
# 137.jpg converted to YOLO format
# Resized and saved 138.jpg
# 138.jpg converted to YOLO format
# Resized and saved 139.jpg
# 139.jpg converted to YOLO format
# Resized and saved 140.jpg
# 140.jpg converted to YOLO format
# Resized and saved 141.jpg
# 141.jpg converted to YOLO format
# Resized and saved 142.jpg
# 142.jpg converted to YOLO format
# Resized and saved 143.jpg
# 143.jpg converted to YOLO format
# Resized and saved 144.jpg
# 144.jpg converted to YOLO format
# Resized and saved 145.jpg
# 145.jpg converted to YOLO format
# Resized and saved 146.jpg
# 146.jpg converted to YOLO format
# Resized and saved 147.jpg
# 147.jpg converted to YOLO format
# Resized and saved 148.jpg
# 148.jpg converted to YOLO format
# Resized and saved 149.jpg
# 149.jpg converted to YOLO format
# Resized and saved 150.jpg
# 150.jpg converted to YOLO format
# Resized and saved 151.jpg
# 151.jpg converted to YOLO format
# Resized and saved 152.jpg
# 152.jpg converted to YOLO format
# Resized and saved 153.jpg
# 153.jpg converted to YOLO format
# Resized and saved 154.jpg
# 154.jpg converted to YOLO format
# Resized and saved 155.jpg
# 155.jpg converted to YOLO format
# Resized and saved 156.jpg
# 156.jpg converted to YOLO format
# Resized and saved 157.jpg
# 157.jpg converted to YOLO format
# Resized and saved 158.jpg
# 158.jpg converted to YOLO format
# Resized and saved 159.jpg
# 159.jpg converted to YOLO format
# Resized and saved 160.jpg
# 160.jpg converted to YOLO format
# Resized and saved 161.jpg
# 161.jpg converted to YOLO format
# Resized and saved 162.jpg
# 162.jpg converted to YOLO format
# Resized and saved 163.jpg
# 163.jpg converted to YOLO format
# Resized and saved 164.jpg
# 164.jpg converted to YOLO format
# Resized and saved 165.jpg
# 165.jpg converted to YOLO format
# Resized and saved 166.jpg
# 166.jpg converted to YOLO format
# Resized and saved 167.jpg
# 167.jpg converted to YOLO format
# Resized and saved 168.jpg
# 168.jpg converted to YOLO format
# Resized and saved 169.jpg
# 169.jpg converted to YOLO format
# Resized and saved 170.jpg
# 170.jpg converted to YOLO format
# Resized and saved 171.jpg
# 171.jpg converted to YOLO format
# Resized and saved 172.jpg
# 172.jpg converted to YOLO format
# Resized and saved 173.jpg
# 173.jpg converted to YOLO format
# Resized and saved 174.jpg
# 174.jpg converted to YOLO format
# Resized and saved 175.jpg
# 175.jpg converted to YOLO format
# Resized and saved 176.jpg
# 176.jpg converted to YOLO format
# Resized and saved 177.jpg
# 177.jpg converted to YOLO format
# Resized and saved 178.jpg
# 178.jpg converted to YOLO format
# Resized and saved 179.jpg
# 179.jpg converted to YOLO format
# Resized and saved 180.jpg
# 180.jpg converted to YOLO format
# Resized and saved 181.jpg
# 181.jpg converted to YOLO format
# Resized and saved 182.jpg
# 182.jpg converted to YOLO format
# Resized and saved 183.jpg
# 183.jpg converted to YOLO format
# Resized and saved 184.jpg
# 184.jpg converted to YOLO format
# Resized and saved 185.jpg
# 185.jpg converted to YOLO format
# Resized and saved 186.jpg
# 186.jpg converted to YOLO format
# Resized and saved 187.jpg
# 187.jpg converted to YOLO format
# Resized and saved 188.jpg
# 188.jpg converted to YOLO format
# Resized and saved 189.jpg
# 189.jpg converted to YOLO format
# Resized and saved 190.jpg
# 190.jpg converted to YOLO format
# Resized and saved 191.jpg
# 191.jpg converted to YOLO format
# Resized and saved 192.jpg
# 192.jpg converted to YOLO format
# Resized and saved 193.jpg
# 193.jpg converted to YOLO format
# Resized and saved 194.jpg
# 194.jpg converted to YOLO format
# Resized and saved 195.jpg
# 195.jpg converted to YOLO format
# Resized and saved 196.jpg
# 196.jpg converted to YOLO format
# Resized and saved 197.jpg
# 197.jpg converted to YOLO format
# Resized and saved 198.jpg
# 198.jpg converted to YOLO format
# Resized and saved 199.jpg
# 199.jpg converted to YOLO format
# Resized and saved 200.jpg
# 200.jpg converted to YOLO format
# Resized and saved 201.jpg
# 201.jpg converted to YOLO format
# Resized and saved 202.jpg
# 202.jpg converted to YOLO format
# Resized and saved 203.jpg
# 203.jpg converted to YOLO format
# Resized and saved 204.jpg
# 204.jpg converted to YOLO format
# Resized and saved 205.jpg
# 205.jpg converted to YOLO format
# Resized and saved 206.jpg
# 206.jpg converted to YOLO format
# Resized and saved 207.jpg
# 207.jpg converted to YOLO format
# Resized and saved 208.jpg
# 208.jpg converted to YOLO format
# Resized and saved 209.jpg
# 209.jpg converted to YOLO format
# Resized and saved 210.jpg
# 210.jpg converted to YOLO format
# Resized and saved 211.jpg
# 211.jpg converted to YOLO format
# Resized and saved 212.jpg
# 212.jpg converted to YOLO format
# Resized and saved 213.jpg
# 213.jpg converted to YOLO format
# Resized and saved 214.jpg
# 214.jpg converted to YOLO format
# Resized and saved 215.jpg
# 215.jpg converted to YOLO format
# Resized and saved 216.jpg
# 216.jpg converted to YOLO format
# Resized and saved 217.jpg
# 217.jpg converted to YOLO format
# Resized and saved 218.jpg
# 218.jpg converted to YOLO format
# Resized and saved 219.jpg
# 219.jpg converted to YOLO format
# Resized and saved 220.jpg
# 220.jpg converted to YOLO format
# Resized and saved 221.jpg
# 221.jpg converted to YOLO format
# Resized and saved 222.jpg
# 222.jpg converted to YOLO format
# Resized and saved 223.jpg
# 223.jpg converted to YOLO format
# Resized and saved 224.jpg
# 224.jpg converted to YOLO format
# Resized and saved 225.jpg
# 225.jpg converted to YOLO format
# Resized and saved 226.jpg
# 226.jpg converted to YOLO format
# Resized and saved 227.jpg
# 227.jpg converted to YOLO format
# Resized and saved 228.jpg
# 228.jpg converted to YOLO format
# Resized and saved 229.jpg
# 229.jpg converted to YOLO format
# Resized and saved 230.jpg
# 230.jpg converted to YOLO format
# Resized and saved 231.jpg
# 231.jpg converted to YOLO format
# Resized and saved 232.jpg
# 232.jpg converted to YOLO format
# Resized and saved 233.jpg
# 233.jpg converted to YOLO format
# Resized and saved 234.jpg
# 234.jpg converted to YOLO format
# Resized and saved 235.jpg
# 235.jpg converted to YOLO format
# Resized and saved 236.jpg
# 236.jpg converted to YOLO format
# Resized and saved 237.jpg
# 237.jpg converted to YOLO format
# Resized and saved 238.jpg
# 238.jpg converted to YOLO format
# Resized and saved 239.jpg
# 239.jpg converted to YOLO format
# Resized and saved 240.jpg
# 240.jpg converted to YOLO format
# Resized and saved 241.jpg
# 241.jpg converted to YOLO format
# Resized and saved 242.jpg
# 242.jpg converted to YOLO format
# Resized and saved 243.jpg
# 243.jpg converted to YOLO format
# Resized and saved 244.jpg
# 244.jpg converted to YOLO format
# Resized and saved 245.jpg
# 245.jpg converted to YOLO format
# Resized and saved 246.jpg
# 246.jpg converted to YOLO format
# Resized and saved 247.jpg
# 247.jpg converted to YOLO format
# Resized and saved 248.jpg
# 248.jpg converted to YOLO format
# Resized and saved 249.jpg
# 249.jpg converted to YOLO format
# Resized and saved 250.jpg
# 250.jpg converted to YOLO format
# Resized and saved 251.jpg
# 251.jpg converted to YOLO format
# Resized and saved 252.jpg
# 252.jpg converted to YOLO format
# Resized and saved 253.jpg
# 253.jpg converted to YOLO format
# Resized and saved 254.jpg
# 254.jpg converted to YOLO format
# Resized and saved 255.jpg
# 255.jpg converted to YOLO format
# Resized and saved 256.jpg
# 256.jpg converted to YOLO format
# Resized and saved 257.jpg
# 257.jpg converted to YOLO format
# Resized and saved 258.jpg
# 258.jpg converted to YOLO format
# Resized and saved 259.jpg
# 259.jpg converted to YOLO format
# Resized and saved 260.jpg
# 260.jpg converted to YOLO format
# Resized and saved 261.jpg
# 261.jpg converted to YOLO format
# Resized and saved 262.jpg
# 262.jpg converted to YOLO format
# Resized and saved 263.jpg
# 263.jpg converted to YOLO format
# Resized and saved 264.jpg
# 264.jpg converted to YOLO format
# Resized and saved 265.jpg
# 265.jpg converted to YOLO format
# Resized and saved 266.jpg
# 266.jpg converted to YOLO format
# Resized and saved 267.jpg
# 267.jpg converted to YOLO format
# Resized and saved 268.jpg
# 268.jpg converted to YOLO format
# Resized and saved 269.jpg
# 269.jpg converted to YOLO format
# Resized and saved 270.jpg
# 270.jpg converted to YOLO format
# Resized and saved 271.jpg
# 271.jpg converted to YOLO format
# Resized and saved 272.jpg
# 272.jpg converted to YOLO format
# Resized and saved 273.jpg
# 273.jpg converted to YOLO format
# Resized and saved 274.jpg
# 274.jpg converted to YOLO format
# Resized and saved 275.jpg
# 275.jpg converted to YOLO format
# Resized and saved 276.jpg
# 276.jpg converted to YOLO format
# Resized and saved 277.jpg
# 277.jpg converted to YOLO format
# Resized and saved 278.jpg
# 278.jpg converted to YOLO format
# Resized and saved 279.jpg
# 279.jpg converted to YOLO format
# Resized and saved 280.jpg
# 280.jpg converted to YOLO format
# Resized and saved 281.jpg
# 281.jpg converted to YOLO format
# Resized and saved 282.jpg
# 282.jpg converted to YOLO format
# Resized and saved 283.jpg
# 283.jpg converted to YOLO format
# Resized and saved 284.jpg
# 284.jpg converted to YOLO format
# Resized and saved 285.jpg
# 285.jpg converted to YOLO format
# Resized and saved 286.jpg
# 286.jpg converted to YOLO format
# Resized and saved 287.jpg
# 287.jpg converted to YOLO format
# Resized and saved 288.jpg
# 288.jpg converted to YOLO format
# Resized and saved 289.jpg
# 289.jpg converted to YOLO format
# Resized and saved 290.jpg
# 290.jpg converted to YOLO format
# Resized and saved 291.jpg
# 291.jpg converted to YOLO format
# Resized and saved 292.jpg
# 292.jpg converted to YOLO format
# Resized and saved 293.jpg
# 293.jpg converted to YOLO format
# Resized and saved 294.jpg
# 294.jpg converted to YOLO format
# Resized and saved 295.jpg
# 295.jpg converted to YOLO format
# Resized and saved 296.jpg
# 296.jpg converted to YOLO format
# Resized and saved 297.jpg
# 297.jpg converted to YOLO format
# Resized and saved 298.jpg
# 298.jpg converted to YOLO format
# Resized and saved 299.jpg
# 299.jpg converted to YOLO format
# Resized and saved 300.jpg
# 300.jpg converted to YOLO format
# Resized and saved 301.jpg
# 301.jpg converted to YOLO format
# Resized and saved 302.jpg
# 302.jpg converted to YOLO format
# Resized and saved 303.jpg
# 303.jpg converted to YOLO format
# Resized and saved 304.jpg
# 304.jpg converted to YOLO format
# Resized and saved 305.jpg
# 305.jpg converted to YOLO format
# Resized and saved 306.jpg
# 306.jpg converted to YOLO format
# Resized and saved 307.jpg
# 307.jpg converted to YOLO format
# Resized and saved 308.jpg
# 308.jpg converted to YOLO format
# Resized and saved 309.jpg
# 309.jpg converted to YOLO format
# Resized and saved 310.jpg
# 310.jpg converted to YOLO format
# Resized and saved 311.jpg
# 311.jpg converted to YOLO format
# Resized and saved 312.jpg
# 312.jpg converted to YOLO format
# Resized and saved 313.jpg
# 313.jpg converted to YOLO format
# Resized and saved 314.jpg
# 314.jpg converted to YOLO format
# Resized and saved 315.jpg
# 315.jpg converted to YOLO format
# Resized and saved 316.jpg
# 316.jpg converted to YOLO format
# Resized and saved 317.jpg
# 317.jpg converted to YOLO format
# Resized and saved 318.jpg
# 318.jpg converted to YOLO format
# Resized and saved 319.jpg
# 319.jpg converted to YOLO format
# Resized and saved 320.jpg
# 320.jpg converted to YOLO format
# Resized and saved 321.jpg
# 321.jpg converted to YOLO format
# Resized and saved 322.jpg
# 322.jpg converted to YOLO format
# Resized and saved 323.jpg
# 323.jpg converted to YOLO format
# Resized and saved 324.jpg
# 324.jpg converted to YOLO format
# Resized and saved 325.jpg
# 325.jpg converted to YOLO format
# Resized and saved 326.jpg
# 326.jpg converted to YOLO format
# Resized and saved 327.jpg
# 327.jpg converted to YOLO format
# Resized and saved 328.jpg
# 328.jpg converted to YOLO format
# Resized and saved 329.jpg
# 329.jpg converted to YOLO format
# Resized and saved 330.jpg
# 330.jpg converted to YOLO format
# Resized and saved 331.jpg
# 331.jpg converted to YOLO format
# Resized and saved 332.jpg
# 332.jpg converted to YOLO format
# Resized and saved 333.jpg
# 333.jpg converted to YOLO format
# Resized and saved 334.jpg
# 334.jpg converted to YOLO format
# Resized and saved 335.jpg
# 335.jpg converted to YOLO format
# Resized and saved 336.jpg
# 336.jpg converted to YOLO format
# Resized and saved 337.jpg
# 337.jpg converted to YOLO format
# Resized and saved 338.jpg
# 338.jpg converted to YOLO format
# Resized and saved 339.jpg
# 339.jpg converted to YOLO format
# Resized and saved 340.jpg
# 340.jpg converted to YOLO format
# Resized and saved 341.jpg
# 341.jpg converted to YOLO format
# Resized and saved 342.jpg
# 342.jpg converted to YOLO format
# Resized and saved 343.jpg
# 343.jpg converted to YOLO format
# Resized and saved 344.jpg
# 344.jpg converted to YOLO format
# Resized and saved 345.jpg
# 345.jpg converted to YOLO format
# Resized and saved 346.jpg
# 346.jpg converted to YOLO format
# Resized and saved 347.jpg
# 347.jpg converted to YOLO format
# Resized and saved 348.jpg
# 348.jpg converted to YOLO format
# Resized and saved 349.jpg
# 349.jpg converted to YOLO format
# Resized and saved 350.jpg
# 350.jpg converted to YOLO format
# Resized and saved 351.jpg
# 351.jpg converted to YOLO format
# Resized and saved 352.jpg
# 352.jpg converted to YOLO format
# Resized and saved 353.jpg
# 353.jpg converted to YOLO format
# Resized and saved 354.jpg
# 354.jpg converted to YOLO format
# Resized and saved 355.jpg
# 355.jpg converted to YOLO format
# Resized and saved 356.jpg
# 356.jpg converted to YOLO format
# Resized and saved 357.jpg
# 357.jpg converted to YOLO format
# Resized and saved 358.jpg
# 358.jpg converted to YOLO format
# Resized and saved 359.jpg
# 359.jpg converted to YOLO format
# Resized and saved 360.jpg
# 360.jpg converted to YOLO format
# Resized and saved 361.jpg
# 361.jpg converted to YOLO format
# Resized and saved 362.jpg
# 362.jpg converted to YOLO format
# Resized and saved 363.jpg
# 363.jpg converted to YOLO format
# Resized and saved 364.jpg
# 364.jpg converted to YOLO format
# Resized and saved 365.jpg
# 365.jpg converted to YOLO format
# Resized and saved 366.jpg
# 366.jpg converted to YOLO format
# Resized and saved 367.jpg
# 367.jpg converted to YOLO format
# Resized and saved 368.jpg
# 368.jpg converted to YOLO format
# Resized and saved 369.jpg
# 369.jpg converted to YOLO format
# Resized and saved 370.jpg
# 370.jpg converted to YOLO format
# Resized and saved 371.jpg
# 371.jpg converted to YOLO format
# Resized and saved 372.jpg
# 372.jpg converted to YOLO format
# Resized and saved 373.jpg
# 373.jpg converted to YOLO format
# Resized and saved 374.jpg
# 374.jpg converted to YOLO format
# Resized and saved 375.jpg
# 375.jpg converted to YOLO format
# Resized and saved 376.jpg
# 376.jpg converted to YOLO format
# Resized and saved 377.jpg
# 377.jpg converted to YOLO format
# Resized and saved 378.jpg
# 378.jpg converted to YOLO format
# Resized and saved 379.jpg
# 379.jpg converted to YOLO format
# Resized and saved 380.jpg
# 380.jpg converted to YOLO format
# Resized and saved 381.jpg
# 381.jpg converted to YOLO format
# Resized and saved 382.jpg
# 382.jpg converted to YOLO format
# Resized and saved 383.jpg
# 383.jpg converted to YOLO format
# Resized and saved 384.jpg
# 384.jpg converted to YOLO format
# Resized and saved 385.jpg
# 385.jpg converted to YOLO format
# Resized and saved 386.jpg
# 386.jpg converted to YOLO format
# Resized and saved 387.jpg
# 387.jpg converted to YOLO format
# Resized and saved 388.jpg
# 388.jpg converted to YOLO format
# Resized and saved 389.jpg
# 389.jpg converted to YOLO format
# Resized and saved 390.jpg
# 390.jpg converted to YOLO format
# Resized and saved 391.jpg
# 391.jpg converted to YOLO format
# Resized and saved 392.jpg
# 392.jpg converted to YOLO format
# Resized and saved 393.jpg
# 393.jpg converted to YOLO format
# Resized and saved 394.jpg
# 394.jpg converted to YOLO format
# Resized and saved 395.jpg
# 395.jpg converted to YOLO format
# Resized and saved 396.jpg
# 396.jpg converted to YOLO format
# Resized and saved 397.jpg
# 397.jpg converted to YOLO format
# Resized and saved 398.jpg
# 398.jpg converted to YOLO format
# Resized and saved 399.jpg
# 399.jpg converted to YOLO format
# Resized and saved 400.jpg
# 400.jpg converted to YOLO format
# Resized and saved 401.jpg
# 401.jpg converted to YOLO format
# Resized and saved 402.jpg
# 402.jpg converted to YOLO format
# Resized and saved 403.jpg
# 403.jpg converted to YOLO format
# Resized and saved 404.jpg
# 404.jpg converted to YOLO format
# Resized and saved 405.jpg
# 405.jpg converted to YOLO format
# Resized and saved 406.jpg
# 406.jpg converted to YOLO format
# Resized and saved 407.jpg
# 407.jpg converted to YOLO format
# Resized and saved 408.jpg
# 408.jpg converted to YOLO format
# Resized and saved 409.jpg
# 409.jpg converted to YOLO format
# Resized and saved 410.jpg
# 410.jpg converted to YOLO format
# Resized and saved 411.jpg
# 411.jpg converted to YOLO format
# Resized and saved 412.jpg
# 412.jpg converted to YOLO format
# Resized and saved 413.jpg
# 413.jpg converted to YOLO format
# Resized and saved 414.jpg
# 414.jpg converted to YOLO format
# Resized and saved 415.jpg
# 415.jpg converted to YOLO format
# Resized and saved 416.jpg
# 416.jpg converted to YOLO format
# Resized and saved 417.jpg
# 417.jpg converted to YOLO format
# Resized and saved 418.jpg
# 418.jpg converted to YOLO format
# Resized and saved 419.jpg
# 419.jpg converted to YOLO format
# Resized and saved 420.jpg
# 420.jpg converted to YOLO format
# Resized and saved 421.jpg
# 421.jpg converted to YOLO format
# Resized and saved 422.jpg
# 422.jpg converted to YOLO format
# Resized and saved 423.jpg
# 423.jpg converted to YOLO format
# Resized and saved 424.jpg
# 424.jpg converted to YOLO format
# Resized and saved 425.jpg
# 425.jpg converted to YOLO format
# Resized and saved 426.jpg
# 426.jpg converted to YOLO format
# Resized and saved 427.jpg
# 427.jpg converted to YOLO format
# Resized and saved 428.jpg
# 428.jpg converted to YOLO format
# Resized and saved 429.jpg
# 429.jpg converted to YOLO format
# Resized and saved 430.jpg
# 430.jpg converted to YOLO format
# Resized and saved 431.jpg
# 431.jpg converted to YOLO format
# Resized and saved 432.jpg
# 432.jpg converted to YOLO format
# Resized and saved 433.jpg
# 433.jpg converted to YOLO format
# Resized and saved 434.jpg
# 434.jpg converted to YOLO format
# Resized and saved 435.jpg
# 435.jpg converted to YOLO format
# Resized and saved 436.jpg
# 436.jpg converted to YOLO format
# Resized and saved 437.jpg
# 437.jpg converted to YOLO format
# Resized and saved 438.jpg
# 438.jpg converted to YOLO format
# Resized and saved 439.jpg
# 439.jpg converted to YOLO format
# Resized and saved 440.jpg
# 440.jpg converted to YOLO format
# Resized and saved 441.jpg
# 441.jpg converted to YOLO format
# Resized and saved 442.jpg
# 442.jpg converted to YOLO format
# Resized and saved 443.jpg
# 443.jpg converted to YOLO format
# Resized and saved 444.jpg
# 444.jpg converted to YOLO format
# Resized and saved 445.jpg
# 445.jpg converted to YOLO format
# Resized and saved 446.jpg
# 446.jpg converted to YOLO format
# Resized and saved 447.jpg
# 447.jpg converted to YOLO format
# Resized and saved 448.jpg
# 448.jpg converted to YOLO format
# Resized and saved 449.jpg
# 449.jpg converted to YOLO format
# Resized and saved 450.jpg
# 450.jpg converted to YOLO format
# Resized and saved 451.jpg
# 451.jpg converted to YOLO format
# Resized and saved 452.jpg
# 452.jpg converted to YOLO format
# Resized and saved 453.jpg
# 453.jpg converted to YOLO format
# Resized and saved 454.jpg
# 454.jpg converted to YOLO format
# Resized and saved 455.jpg
# 455.jpg converted to YOLO format
# Resized and saved 456.jpg
# 456.jpg converted to YOLO format
# Resized and saved 457.jpg
# 457.jpg converted to YOLO format
# Resized and saved 458.jpg
# 458.jpg converted to YOLO format
# Resized and saved 459.jpg
# 459.jpg converted to YOLO format
# Resized and saved 460.jpg
# 460.jpg converted to YOLO format
# Resized and saved 461.jpg
# 461.jpg converted to YOLO format
# Resized and saved 462.jpg
# 462.jpg converted to YOLO format
# Resized and saved 463.jpg
# 463.jpg converted to YOLO format
# Resized and saved 464.jpg
# 464.jpg converted to YOLO format
# Resized and saved 465.jpg
# 465.jpg converted to YOLO format
# Resized and saved 466.jpg
# 466.jpg converted to YOLO format
# Resized and saved 467.jpg
# 467.jpg converted to YOLO format
# Resized and saved 468.jpg
# 468.jpg converted to YOLO format
# Resized and saved 469.jpg
# 469.jpg converted to YOLO format
# Resized and saved 470.jpg
# 470.jpg converted to YOLO format
# Resized and saved 471.jpg
# 471.jpg converted to YOLO format
# Resized and saved 472.jpg
# 472.jpg converted to YOLO format
# Resized and saved 473.jpg
# 473.jpg converted to YOLO format
# Resized and saved 474.jpg
# 474.jpg converted to YOLO format
# Resized and saved 475.jpg
# 475.jpg converted to YOLO format
# Resized and saved 476.jpg
# 476.jpg converted to YOLO format
# Resized and saved 477.jpg
# 477.jpg converted to YOLO format
# Resized and saved 478.jpg
# 478.jpg converted to YOLO format
# Resized and saved 479.jpg
# 479.jpg converted to YOLO format
# Resized and saved 480.jpg
# 480.jpg converted to YOLO format
# Resized and saved 481.jpg
# 481.jpg converted to YOLO format
# Resized and saved 482.jpg
# 482.jpg converted to YOLO format
# Resized and saved 483.jpg
# 483.jpg converted to YOLO format
# Resized and saved 484.jpg
# 484.jpg converted to YOLO format
# Resized and saved 485.jpg
# 485.jpg converted to YOLO format
# Resized and saved 486.jpg
# 486.jpg converted to YOLO format
# Resized and saved 487.jpg
# 487.jpg converted to YOLO format
# Resized and saved 488.jpg
# 488.jpg converted to YOLO format
# Resized and saved 489.jpg
# 489.jpg converted to YOLO format
# Resized and saved 490.jpg
# 490.jpg converted to YOLO format
# Resized and saved 491.jpg
# 491.jpg converted to YOLO format
# Resized and saved 492.jpg
# 492.jpg converted to YOLO format
# Resized and saved 493.jpg
# 493.jpg converted to YOLO format
# Resized and saved 494.jpg
# 494.jpg converted to YOLO format
# Resized and saved 495.jpg
# 495.jpg converted to YOLO format
# Resized and saved 496.jpg
# 496.jpg converted to YOLO format
# Resized and saved 497.jpg
# 497.jpg converted to YOLO format
# Resized and saved 498.jpg
# 498.jpg converted to YOLO format
# Resized and saved 499.jpg
# 499.jpg converted to YOLO format
# Resized and saved 500.jpg
# 500.jpg converted to YOLO format
# Resized and saved 501.jpg
# 501.jpg converted to YOLO format
# Resized and saved 502.jpg
# 502.jpg converted to YOLO format
# Resized and saved 503.jpg
# 503.jpg converted to YOLO format
# Resized and saved 504.jpg
# 504.jpg converted to YOLO format
# Resized and saved 505.jpg
# 505.jpg converted to YOLO format
# Resized and saved 506.jpg
# 506.jpg converted to YOLO format
# Resized and saved 507.jpg
# 507.jpg converted to YOLO format
# Resized and saved 508.jpg
# 508.jpg converted to YOLO format
# Resized and saved 509.jpg
# 509.jpg converted to YOLO format
# Resized and saved 510.jpg
# 510.jpg converted to YOLO format
# Resized and saved 511.jpg
# 511.jpg converted to YOLO format
# Resized and saved 512.jpg
# 512.jpg converted to YOLO format
# Resized and saved 513.jpg
# 513.jpg converted to YOLO format
# Resized and saved 514.jpg
# 514.jpg converted to YOLO format
# Resized and saved 515.jpg
# 515.jpg converted to YOLO format
# Resized and saved 516.jpg
# 516.jpg converted to YOLO format
# Resized and saved 517.jpg
# 517.jpg converted to YOLO format
# Resized and saved 518.jpg
# 518.jpg converted to YOLO format
# Resized and saved 519.jpg
# 519.jpg converted to YOLO format
# Resized and saved 520.jpg
# 520.jpg converted to YOLO format
# Resized and saved 521.jpg
# 521.jpg converted to YOLO format
# Resized and saved 522.jpg
# 522.jpg converted to YOLO format
# Resized and saved 523.jpg
# 523.jpg converted to YOLO format
# Resized and saved 524.jpg
# 524.jpg converted to YOLO format
# Resized and saved 525.jpg
# 525.jpg converted to YOLO format
# Resized and saved 526.jpg
# 526.jpg converted to YOLO format
# Resized and saved 527.jpg
# 527.jpg converted to YOLO format
# Resized and saved 528.jpg
# 528.jpg converted to YOLO format
# Resized and saved 529.jpg
# 529.jpg converted to YOLO format
# Resized and saved 530.jpg
# 530.jpg converted to YOLO format
# Resized and saved 531.jpg
# 531.jpg converted to YOLO format
# Resized and saved 532.jpg
# 532.jpg converted to YOLO format
# Resized and saved 533.jpg
# 533.jpg converted to YOLO format
# Resized and saved 534.jpg
# 534.jpg converted to YOLO format
# Resized and saved 535.jpg
# 535.jpg converted to YOLO format
# Resized and saved 536.jpg
# 536.jpg converted to YOLO format
# Resized and saved 537.jpg
# 537.jpg converted to YOLO format
# Resized and saved 538.jpg
# 538.jpg converted to YOLO format
# Resized and saved 539.jpg
# 539.jpg converted to YOLO format
# Resized and saved 540.jpg
# 540.jpg converted to YOLO format
# Resized and saved 541.jpg
# 541.jpg converted to YOLO format
# Resized and saved 542.jpg
# 542.jpg converted to YOLO format
# Resized and saved 543.jpg
# 543.jpg converted to YOLO format
# Resized and saved 544.jpg
# 544.jpg converted to YOLO format
# Resized and saved 545.jpg
# 545.jpg converted to YOLO format
# Resized and saved 546.jpg
# 546.jpg converted to YOLO format
# Resized and saved 547.jpg
# 547.jpg converted to YOLO format
# Resized and saved 548.jpg
# 548.jpg converted to YOLO format
# Resized and saved 549.jpg
# 549.jpg converted to YOLO format
# Resized and saved 550.jpg
# 550.jpg converted to YOLO format
# Resized and saved 551.jpg
# 551.jpg converted to YOLO format
# Resized and saved 552.jpg
# 552.jpg converted to YOLO format
# Resized and saved 553.jpg
# 553.jpg converted to YOLO format
# Resized and saved 554.jpg
# 554.jpg converted to YOLO format
# Resized and saved 555.jpg
# 555.jpg converted to YOLO format
# Resized and saved 556.jpg
# 556.jpg converted to YOLO format
# Resized and saved 557.jpg
# 557.jpg converted to YOLO format
# Resized and saved 558.jpg
# 558.jpg converted to YOLO format
# Resized and saved 559.jpg
# 559.jpg converted to YOLO format
# Resized and saved 560.jpg
# 560.jpg converted to YOLO format
# Resized and saved 561.jpg
# 561.jpg converted to YOLO format
# Resized and saved 562.jpg
# 562.jpg converted to YOLO format
# Resized and saved 563.jpg
# 563.jpg converted to YOLO format
# Resized and saved 564.jpg
# 564.jpg converted to YOLO format
# Resized and saved 565.jpg
# 565.jpg converted to YOLO format
# Resized and saved 566.jpg
# 566.jpg converted to YOLO format
# Resized and saved 567.jpg
# 567.jpg converted to YOLO format
# Resized and saved 568.jpg
# 568.jpg converted to YOLO format
# Resized and saved 569.jpg
# 569.jpg converted to YOLO format
# Resized and saved 570.jpg
# 570.jpg converted to YOLO format
# Resized and saved 571.jpg
# 571.jpg converted to YOLO format
# Resized and saved 572.jpg
# 572.jpg converted to YOLO format
# Resized and saved 573.jpg
# 573.jpg converted to YOLO format
# Resized and saved 574.jpg
# 574.jpg converted to YOLO format
# Resized and saved 575.jpg
# 575.jpg converted to YOLO format
# Resized and saved 576.jpg
# 576.jpg converted to YOLO format
# Resized and saved 577.jpg
# 577.jpg converted to YOLO format
# Resized and saved 578.jpg
# 578.jpg converted to YOLO format
# Resized and saved 579.jpg
# 579.jpg converted to YOLO format
# Resized and saved 580.jpg
# 580.jpg converted to YOLO format
# Resized and saved 581.jpg
# 581.jpg converted to YOLO format
# Resized and saved 582.jpg
# 582.jpg converted to YOLO format
# Resized and saved 583.jpg
# 583.jpg converted to YOLO format
# Resized and saved 584.jpg
# 584.jpg converted to YOLO format
# Resized and saved 585.jpg
# 585.jpg converted to YOLO format
# Resized and saved 586.jpg
# 586.jpg converted to YOLO format
# Resized and saved 587.jpg
# 587.jpg converted to YOLO format
# Resized and saved 588.jpg
# 588.jpg converted to YOLO format
# Resized and saved 589.jpg
# 589.jpg converted to YOLO format
# Resized and saved 590.jpg
# 590.jpg converted to YOLO format
# Resized and saved 591.jpg
# 591.jpg converted to YOLO format
# Resized and saved 592.jpg
# 592.jpg converted to YOLO format
# Resized and saved 593.jpg
# 593.jpg converted to YOLO format
# Resized and saved 594.jpg
# 594.jpg converted to YOLO format
# Resized and saved 595.jpg
# 595.jpg converted to YOLO format
# Resized and saved 596.jpg
# 596.jpg converted to YOLO format
# Resized and saved 597.jpg
# 597.jpg converted to YOLO format
# Resized and saved 598.jpg
# 598.jpg converted to YOLO format
# Resized and saved 599.jpg
# 599.jpg converted to YOLO format
# Resized and saved 600.jpg
# 600.jpg converted to YOLO format
# Resized and saved 601.jpg
# 601.jpg converted to YOLO format
# Resized and saved 602.jpg
# 602.jpg converted to YOLO format
# Resized and saved 603.jpg
# 603.jpg converted to YOLO format
# Resized and saved 604.jpg
# 604.jpg converted to YOLO format
# Resized and saved 605.jpg
# 605.jpg converted to YOLO format
# Resized and saved 606.jpg
# 606.jpg converted to YOLO format
# Resized and saved 607.jpg
# 607.jpg converted to YOLO format
# Resized and saved 608.jpg
# 608.jpg converted to YOLO format
# Resized and saved 609.jpg
# 609.jpg converted to YOLO format
# Resized and saved 610.jpg
# 610.jpg converted to YOLO format
# Resized and saved 611.jpg
# 611.jpg converted to YOLO format
# Resized and saved 612.jpg
# 612.jpg converted to YOLO format
# Resized and saved 613.jpg
# 613.jpg converted to YOLO format
# Resized and saved 614.jpg
# 614.jpg converted to YOLO format
# Resized and saved 615.jpg
# 615.jpg converted to YOLO format
# Resized and saved 616.jpg
# 616.jpg converted to YOLO format
# Resized and saved 617.jpg
# 617.jpg converted to YOLO format
# Resized and saved 618.jpg
# 618.jpg converted to YOLO format
# Resized and saved 619.jpg
# 619.jpg converted to YOLO format
# Resized and saved 620.jpg
# 620.jpg converted to YOLO format
# Resized and saved 621.jpg
# 621.jpg converted to YOLO format
# Resized and saved 622.jpg
# 622.jpg converted to YOLO format
# Resized and saved 623.jpg
# 623.jpg converted to YOLO format
# Resized and saved 624.jpg
# 624.jpg converted to YOLO format
# Resized and saved 625.jpg
# 625.jpg converted to YOLO format
# Resized and saved 626.jpg
# 626.jpg converted to YOLO format
# Resized and saved 627.jpg
# 627.jpg converted to YOLO format
# Resized and saved 628.jpg
# 628.jpg converted to YOLO format
# Resized and saved 629.jpg
# 629.jpg converted to YOLO format
# Resized and saved 630.jpg
# 630.jpg converted to YOLO format
# Resized and saved 631.jpg
# 631.jpg converted to YOLO format
# Resized and saved 632.jpg
# 632.jpg converted to YOLO format
# Resized and saved 633.jpg
# 633.jpg converted to YOLO format
# Resized and saved 634.jpg
# 634.jpg converted to YOLO format
# Resized and saved 635.jpg
# 635.jpg converted to YOLO format
# Resized and saved 636.jpg
# 636.jpg converted to YOLO format
# Resized and saved 637.jpg
# 637.jpg converted to YOLO format
# Resized and saved 638.jpg
# 638.jpg converted to YOLO format
# Resized and saved 639.jpg
# 639.jpg converted to YOLO format
# Resized and saved 640.jpg
# 640.jpg converted to YOLO format
# Resized and saved 641.jpg
# 641.jpg converted to YOLO format
# Resized and saved 642.jpg
# 642.jpg converted to YOLO format
# Resized and saved 643.jpg
# 643.jpg converted to YOLO format
# Resized and saved 644.jpg
# 644.jpg converted to YOLO format
# Resized and saved 645.jpg
# 645.jpg converted to YOLO format
# Resized and saved 646.jpg
# 646.jpg converted to YOLO format
# Resized and saved 647.jpg
# 647.jpg converted to YOLO format
# Resized and saved 648.jpg
# 648.jpg converted to YOLO format
# Resized and saved 649.jpg
# 649.jpg converted to YOLO format
# Resized and saved 650.jpg
# 650.jpg converted to YOLO format
# Resized and saved 651.jpg
# 651.jpg converted to YOLO format
# Resized and saved 652.jpg
# 652.jpg converted to YOLO format
# Resized and saved 653.jpg
# 653.jpg converted to YOLO format
# Resized and saved 654.jpg
# 654.jpg converted to YOLO format
# Resized and saved 655.jpg
# 655.jpg converted to YOLO format
# Resized and saved 656.jpg
# 656.jpg converted to YOLO format
# Resized and saved 657.jpg
# 657.jpg converted to YOLO format
# Resized and saved 658.jpg
# 658.jpg converted to YOLO format
# Resized and saved 659.jpg
# 659.jpg converted to YOLO format
# Resized and saved 660.jpg
# 660.jpg converted to YOLO format
# Resized and saved 661.jpg
# 661.jpg converted to YOLO format
# Resized and saved 662.jpg
# 662.jpg converted to YOLO format
# Resized and saved 663.jpg
# 663.jpg converted to YOLO format
# Resized and saved 664.jpg
# 664.jpg converted to YOLO format
# Resized and saved 665.jpg
# 665.jpg converted to YOLO format
# Resized and saved 666.jpg
# 666.jpg converted to YOLO format
# Resized and saved 667.jpg
# 667.jpg converted to YOLO format
# Resized and saved 668.jpg
# 668.jpg converted to YOLO format
# Resized and saved 669.jpg
# 669.jpg converted to YOLO format
# Resized and saved 670.jpg
# 670.jpg converted to YOLO format
# Resized and saved 671.jpg
# 671.jpg converted to YOLO format
# Resized and saved 672.jpg
# 672.jpg converted to YOLO format
# Resized and saved 673.jpg
# 673.jpg converted to YOLO format
# Resized and saved 674.jpg
# 674.jpg converted to YOLO format
# Resized and saved 675.jpg
# 675.jpg converted to YOLO format
# Resized and saved 676.jpg
# 676.jpg converted to YOLO format
# Resized and saved 677.jpg
# 677.jpg converted to YOLO format
# Resized and saved 678.jpg
# 678.jpg converted to YOLO format
# Resized and saved 679.jpg
# 679.jpg converted to YOLO format
# Resized and saved 680.jpg
# 680.jpg converted to YOLO format
# Resized and saved 681.jpg
# 681.jpg converted to YOLO format
# Resized and saved 682.jpg
# 682.jpg converted to YOLO format
# Resized and saved 683.jpg
# 683.jpg converted to YOLO format
# Resized and saved 684.jpg
# 684.jpg converted to YOLO format
# Resized and saved 685.jpg
# 685.jpg converted to YOLO format
# Resized and saved 686.jpg
# 686.jpg converted to YOLO format
# Resized and saved 687.jpg
# 687.jpg converted to YOLO format
# Resized and saved 688.jpg
# 688.jpg converted to YOLO format
# Resized and saved 689.jpg
# 689.jpg converted to YOLO format
# Resized and saved 690.jpg
# 690.jpg converted to YOLO format
# Resized and saved 691.jpg
# 691.jpg converted to YOLO format
# Resized and saved 692.jpg
# 692.jpg converted to YOLO format
# Resized and saved 693.jpg
# 693.jpg converted to YOLO format
# Resized and saved 694.jpg
# 694.jpg converted to YOLO format
# Resized and saved 695.jpg
# 695.jpg converted to YOLO format
# Resized and saved 696.jpg
# 696.jpg converted to YOLO format
# Resized and saved 697.jpg
# 697.jpg converted to YOLO format
# Resized and saved 698.jpg
# 698.jpg converted to YOLO format
# Resized and saved 699.jpg
# 699.jpg converted to YOLO format
# Resized and saved 700.jpg
# 700.jpg converted to YOLO format
# Resized and saved 701.jpg
# 701.jpg converted to YOLO format
# Resized and saved 702.jpg
# 702.jpg converted to YOLO format
# Resized and saved 703.jpg
# 703.jpg converted to YOLO format
# Resized and saved 704.jpg
# 704.jpg converted to YOLO format
# Resized and saved 705.jpg
# 705.jpg converted to YOLO format
# Resized and saved 706.jpg
# 706.jpg converted to YOLO format
# Resized and saved 707.jpg
# 707.jpg converted to YOLO format
# Resized and saved 708.jpg
# 708.jpg converted to YOLO format
# Resized and saved 709.jpg
# 709.jpg converted to YOLO format
# Resized and saved 710.jpg
# 710.jpg converted to YOLO format
# Resized and saved 711.jpg
# 711.jpg converted to YOLO format
# Resized and saved 712.jpg
# 712.jpg converted to YOLO format
# Resized and saved 713.jpg
# 713.jpg converted to YOLO format
# Resized and saved 714.jpg
# 714.jpg converted to YOLO format
# Resized and saved 715.jpg
# 715.jpg converted to YOLO format
# Resized and saved 716.jpg
# 716.jpg converted to YOLO format
# Resized and saved 717.jpg
# 717.jpg converted to YOLO format
# Resized and saved 718.jpg
# 718.jpg converted to YOLO format
# Resized and saved 719.jpg
# 719.jpg converted to YOLO format
# Resized and saved 720.jpg
# 720.jpg converted to YOLO format
# Resized and saved 721.jpg
# 721.jpg converted to YOLO format
# Resized and saved 722.jpg
# 722.jpg converted to YOLO format
# Resized and saved 723.jpg
# 723.jpg converted to YOLO format
# Resized and saved 724.jpg
# 724.jpg converted to YOLO format
# Resized and saved 725.jpg
# 725.jpg converted to YOLO format
# Resized and saved 726.jpg
# 726.jpg converted to YOLO format
# Resized and saved 727.jpg
# 727.jpg converted to YOLO format
# Resized and saved 728.jpg
# 728.jpg converted to YOLO format
# Resized and saved 729.jpg
# 729.jpg converted to YOLO format
# Resized and saved 730.jpg
# 730.jpg converted to YOLO format
# Resized and saved 731.jpg
# 731.jpg converted to YOLO format
# Resized and saved 732.jpg
# 732.jpg converted to YOLO format
# Resized and saved 733.jpg
# 733.jpg converted to YOLO format
# Resized and saved 734.jpg
# 734.jpg converted to YOLO format
# Resized and saved 735.jpg
# 735.jpg converted to YOLO format
# Resized and saved 736.jpg
# 736.jpg converted to YOLO format
# Resized and saved 737.jpg
# 737.jpg converted to YOLO format
# Resized and saved 738.jpg
# 738.jpg converted to YOLO format
# Resized and saved 739.jpg
# 739.jpg converted to YOLO format
# Resized and saved 740.jpg
# 740.jpg converted to YOLO format
# Resized and saved 741.jpg
# 741.jpg converted to YOLO format
# Resized and saved 742.jpg
# 742.jpg converted to YOLO format
# Resized and saved 743.jpg
# 743.jpg converted to YOLO format
# Resized and saved 744.jpg
# 744.jpg converted to YOLO format
# Resized and saved 745.jpg
# 745.jpg converted to YOLO format
# Resized and saved 746.jpg
# 746.jpg converted to YOLO format
# Resized and saved 747.jpg
# 747.jpg converted to YOLO format
# Resized and saved 748.jpg
# 748.jpg converted to YOLO format
# Resized and saved 749.jpg
# 749.jpg converted to YOLO format
# Resized and saved 750.jpg
# 750.jpg converted to YOLO format
# Resized and saved 751.jpg
# 751.jpg converted to YOLO format
# Resized and saved 752.jpg
# 752.jpg converted to YOLO format
# Resized and saved 753.jpg
# 753.jpg converted to YOLO format
# Resized and saved 754.jpg
# 754.jpg converted to YOLO format
# Resized and saved 755.jpg
# 755.jpg converted to YOLO format
# Resized and saved 756.jpg
# 756.jpg converted to YOLO format
# Resized and saved 757.jpg
# 757.jpg converted to YOLO format
# Resized and saved 758.jpg
# 758.jpg converted to YOLO format
# Resized and saved 759.jpg
# 759.jpg converted to YOLO format
# Resized and saved 760.jpg
# 760.jpg converted to YOLO format
# Resized and saved 761.jpg
# 761.jpg converted to YOLO format
# Resized and saved 762.jpg
# 762.jpg converted to YOLO format
# Resized and saved 763.jpg
# 763.jpg converted to YOLO format
# Resized and saved 764.jpg
# 764.jpg converted to YOLO format
# Resized and saved 765.jpg
# 765.jpg converted to YOLO format
# Resized and saved 766.jpg
# 766.jpg converted to YOLO format
# Resized and saved 767.jpg
# 767.jpg converted to YOLO format
# Resized and saved 768.jpg
# 768.jpg converted to YOLO format
# Resized and saved 769.jpg
# 769.jpg converted to YOLO format
# Resized and saved 770.jpg
# 770.jpg converted to YOLO format
# Resized and saved 771.jpg
# 771.jpg converted to YOLO format
# Resized and saved 772.jpg
# 772.jpg converted to YOLO format
# Resized and saved 773.jpg
# 773.jpg converted to YOLO format
# Resized and saved 774.jpg
# 774.jpg converted to YOLO format
# Resized and saved 775.jpg
# 775.jpg converted to YOLO format
# Resized and saved 776.jpg
# 776.jpg converted to YOLO format
# Resized and saved 777.jpg
# 777.jpg converted to YOLO format
# Resized and saved 778.jpg
# 778.jpg converted to YOLO format
# Resized and saved 779.jpg
# 779.jpg converted to YOLO format
# Resized and saved 780.jpg
# 780.jpg converted to YOLO format
# Resized and saved 781.jpg
# 781.jpg converted to YOLO format
# Resized and saved 782.jpg
# 782.jpg converted to YOLO format
# Resized and saved 783.jpg
# 783.jpg converted to YOLO format
# Resized and saved 784.jpg
# 784.jpg converted to YOLO format
# Resized and saved 785.jpg
# 785.jpg converted to YOLO format
# Resized and saved 786.jpg
# 786.jpg converted to YOLO format
# Resized and saved 787.jpg
# 787.jpg converted to YOLO format
# Resized and saved 788.jpg
# 788.jpg converted to YOLO format
# Resized and saved 789.jpg
# 789.jpg converted to YOLO format
# Resized and saved 790.jpg
# 790.jpg converted to YOLO format
# Resized and saved 791.jpg
# 791.jpg converted to YOLO format
# Resized and saved 792.jpg
# 792.jpg converted to YOLO format
# Resized and saved 793.jpg
# 793.jpg converted to YOLO format
# Resized and saved 794.jpg
# 794.jpg converted to YOLO format
# Resized and saved 795.jpg
# 795.jpg converted to YOLO format
# Resized and saved 796.jpg
# 796.jpg converted to YOLO format
# Resized and saved 797.jpg
# 797.jpg converted to YOLO format
# Resized and saved 798.jpg
# 798.jpg converted to YOLO format
# Resized and saved 799.jpg
# 799.jpg converted to YOLO format
# Resized and saved 800.jpg
# 800.jpg converted to YOLO format
# Resized and saved 801.jpg
# 801.jpg converted to YOLO format
# Resized and saved 802.jpg
# 802.jpg converted to YOLO format
# Resized and saved 803.jpg
# 803.jpg converted to YOLO format
# Resized and saved 804.jpg
# 804.jpg converted to YOLO format
# Resized and saved 805.jpg
# 805.jpg converted to YOLO format
# Resized and saved 806.jpg
# 806.jpg converted to YOLO format
# Resized and saved 807.jpg
# 807.jpg converted to YOLO format
# Resized and saved 808.jpg
# 808.jpg converted to YOLO format
# Resized and saved 809.jpg
# 809.jpg converted to YOLO format
# Resized and saved 810.jpg
# 810.jpg converted to YOLO format
# Resized and saved 811.jpg
# 811.jpg converted to YOLO format
# Resized and saved 812.jpg
# 812.jpg converted to YOLO format
# Resized and saved 813.jpg
# 813.jpg converted to YOLO format
# Resized and saved 814.jpg
# 814.jpg converted to YOLO format
# Resized and saved 815.jpg
# 815.jpg converted to YOLO format
# Resized and saved 816.jpg
# 816.jpg converted to YOLO format
# ...
# Resized and saved 2830.jpg
# 2830.jpg converted to YOLO format
# Resized and saved 2831.jpg
# 2831.jpg converted to YOLO format
# Resized and saved 2832.jpg
# 2832.jpg converted to YOLO format
# Resized and saved 2833.jpg
# 2833.jpg converted to YOLO format
# Resized and saved 2834.jpg
# 2834.jpg converted to YOLO format
# Resized and saved 2835.jpg
# 2835.jpg converted to YOLO format
# Resized and saved 2836.jpg
# 2836.jpg converted to YOLO format
# Resized and saved 2837.jpg
# 2837.jpg converted to YOLO format
# Resized and saved 2838.jpg
# 2838.jpg converted to YOLO format
# Resized and saved 2839.jpg
# 2839.jpg converted to YOLO format
# Resized and saved 2840.jpg
# 2840.jpg converted to YOLO format
# Resized and saved 2841.jpg
# 2841.jpg converted to YOLO format
# Resized and saved 2842.jpg
# 2842.jpg converted to YOLO format
# Resized and saved 2843.jpg
# 2843.jpg converted to YOLO format
# Resized and saved 2844.jpg
# 2844.jpg converted to YOLO format
# Resized and saved 2845.jpg
# 2845.jpg converted to YOLO format
# Resized and saved 2846.jpg
# 2846.jpg converted to YOLO format
# Resized and saved 2847.jpg
# 2847.jpg converted to YOLO format
# Resized and saved 2848.jpg
# 2848.jpg converted to YOLO format
# Resized and saved 2849.jpg
# 2849.jpg converted to YOLO format
# Resized and saved 2850.jpg
# 2850.jpg converted to YOLO format
# Resized and saved 2851.jpg
# 2851.jpg converted to YOLO format
# Resized and saved 2852.jpg
# 2852.jpg converted to YOLO format
# Resized and saved 2853.jpg
# 2853.jpg converted to YOLO format
# Resized and saved 2854.jpg
# 2854.jpg converted to YOLO format
# Resized and saved 2855.jpg
# 2855.jpg converted to YOLO format
# Resized and saved 2856.jpg
# 2856.jpg converted to YOLO format
# Resized and saved 2857.jpg
# 2857.jpg converted to YOLO format
# Resized and saved 2858.jpg
# 2858.jpg converted to YOLO format
# Resized and saved 2859.jpg
# 2859.jpg converted to YOLO format
# Resized and saved 2860.jpg
# 2860.jpg converted to YOLO format
# Resized and saved 2861.jpg
# 2861.jpg converted to YOLO format
# Resized and saved 2862.jpg
# 2862.jpg converted to YOLO format
# Resized and saved 2863.jpg
# 2863.jpg converted to YOLO format
# Resized and saved 2864.jpg
# 2864.jpg converted to YOLO format
# Resized and saved 2865.jpg
# 2865.jpg converted to YOLO format
# Resized and saved 2866.jpg
# 2866.jpg converted to YOLO format
# Resized and saved 2867.jpg
# 2867.jpg converted to YOLO format
# Resized and saved 2868.jpg
# 2868.jpg converted to YOLO format
# Resized and saved 2869.jpg
# 2869.jpg converted to YOLO format
# Resized and saved 2870.jpg
# 2870.jpg converted to YOLO format
# Resized and saved 2871.jpg
# 2871.jpg converted to YOLO format
# Resized and saved 2872.jpg
# 2872.jpg converted to YOLO format
# Resized and saved 2873.jpg
# 2873.jpg converted to YOLO format
# Resized and saved 2874.jpg
# 2874.jpg converted to YOLO format
# Resized and saved 2875.jpg
# 2875.jpg converted to YOLO format
# Resized and saved 2876.jpg
# 2876.jpg converted to YOLO format
# Resized and saved 2877.jpg
# 2877.jpg converted to YOLO format
# Resized and saved 2878.jpg
# 2878.jpg converted to YOLO format
# Resized and saved 2879.jpg
# 2879.jpg converted to YOLO format
# Resized and saved 2880.jpg
# 2880.jpg converted to YOLO format
# Resized and saved 2881.jpg
# 2881.jpg converted to YOLO format
# Resized and saved 2882.jpg
# 2882.jpg converted to YOLO format
# Resized and saved 2883.jpg
# 2883.jpg converted to YOLO format
# Resized and saved 2884.jpg
# 2884.jpg converted to YOLO format
# Resized and saved 2885.jpg
# 2885.jpg converted to YOLO format
# Resized and saved 2886.jpg
# 2886.jpg converted to YOLO format
# Resized and saved 2887.jpg
# 2887.jpg converted to YOLO format
# Resized and saved 2888.jpg
# 2888.jpg converted to YOLO format
# Resized and saved 2889.jpg
# 2889.jpg converted to YOLO format
# Resized and saved 2890.jpg
# 2890.jpg converted to YOLO format
# Resized and saved 2891.jpg
# 2891.jpg converted to YOLO format
# Resized and saved 2892.jpg
# 2892.jpg converted to YOLO format
# Resized and saved 2893.jpg
# 2893.jpg converted to YOLO format
# Resized and saved 2894.jpg
# 2894.jpg converted to YOLO format
# Resized and saved 2895.jpg
# 2895.jpg converted to YOLO format
# Resized and saved 2896.jpg
# 2896.jpg converted to YOLO format
# Resized and saved 2897.jpg
# 2897.jpg converted to YOLO format
# Resized and saved 2898.jpg
# 2898.jpg converted to YOLO format
# Resized and saved 2899.jpg
# 2899.jpg converted to YOLO format
# Resized and saved 2900.jpg
# 2900.jpg converted to YOLO format
# Resized and saved 2901.jpg
# 2901.jpg converted to YOLO format
# Resized and saved 2902.jpg
# 2902.jpg converted to YOLO format
# Resized and saved 2903.jpg
# 2903.jpg converted to YOLO format
# Resized and saved 2904.jpg
# 2904.jpg converted to YOLO format
# Resized and saved 2905.jpg
# 2905.jpg converted to YOLO format
# Resized and saved 2906.jpg
# 2906.jpg converted to YOLO format
# Resized and saved 2907.jpg
# 2907.jpg converted to YOLO format
# Resized and saved 2908.jpg
# 2908.jpg converted to YOLO format
# Resized and saved 2909.jpg
# 2909.jpg converted to YOLO format
# Resized and saved 2910.jpg
# 2910.jpg converted to YOLO format
# Resized and saved 2911.jpg
# 2911.jpg converted to YOLO format
# Resized and saved 2912.jpg
# 2912.jpg converted to YOLO format
# Resized and saved 2913.jpg
# 2913.jpg converted to YOLO format
# Resized and saved 2914.jpg
# 2914.jpg converted to YOLO format
# Resized and saved 2915.jpg
# 2915.jpg converted to YOLO format
# Resized and saved 2916.jpg
# 2916.jpg converted to YOLO format
# Resized and saved 2917.jpg
# 2917.jpg converted to YOLO format
# Resized and saved 2918.jpg
# 2918.jpg converted to YOLO format
# Resized and saved 2919.jpg
# 2919.jpg converted to YOLO format
# Resized and saved 2920.jpg
# 2920.jpg converted to YOLO format
# Resized and saved 2921.jpg
# 2921.jpg converted to YOLO format
# Resized and saved 2922.jpg
# 2922.jpg converted to YOLO format
# Resized and saved 2923.jpg
# 2923.jpg converted to YOLO format
# Resized and saved 2924.jpg
# 2924.jpg converted to YOLO format
# Resized and saved 2925.jpg
# 2925.jpg converted to YOLO format
# Resized and saved 2926.jpg
# 2926.jpg converted to YOLO format
# Resized and saved 2927.jpg
# 2927.jpg converted to YOLO format
# Resized and saved 2928.jpg
# 2928.jpg converted to YOLO format
# Resized and saved 2929.jpg
# 2929.jpg converted to YOLO format
# Resized and saved 2930.jpg
# 2930.jpg converted to YOLO format
# Resized and saved 2931.jpg
# 2931.jpg converted to YOLO format
# Resized and saved 2932.jpg
# 2932.jpg converted to YOLO format
# Resized and saved 2933.jpg
# 2933.jpg converted to YOLO format
# Resized and saved 2934.jpg
# 2934.jpg converted to YOLO format
# Resized and saved 2935.jpg
# 2935.jpg converted to YOLO format
# Resized and saved 2936.jpg
# 2936.jpg converted to YOLO format
# Resized and saved 2937.jpg
# 2937.jpg converted to YOLO format
# Resized and saved 2938.jpg
# 2938.jpg converted to YOLO format
# Resized and saved 2939.jpg
# 2939.jpg converted to YOLO format
# Resized and saved 2940.jpg
# 2940.jpg converted to YOLO format
# Resized and saved 2941.jpg
# 2941.jpg converted to YOLO format
# Resized and saved 2942.jpg
# 2942.jpg converted to YOLO format
# Resized and saved 2943.jpg
# 2943.jpg converted to YOLO format
# Resized and saved 2944.jpg
# 2944.jpg converted to YOLO format
# Resized and saved 2945.jpg
# 2945.jpg converted to YOLO format
# Resized and saved 2946.jpg
# 2946.jpg converted to YOLO format
# Resized and saved 2947.jpg
# 2947.jpg converted to YOLO format
# Resized and saved 2948.jpg
# 2948.jpg converted to YOLO format
# Resized and saved 2949.jpg
# 2949.jpg converted to YOLO format
# Resized and saved 2950.jpg
# 2950.jpg converted to YOLO format
# Resized and saved 2951.jpg
# 2951.jpg converted to YOLO format
# Resized and saved 2952.jpg
# 2952.jpg converted to YOLO format
# Resized and saved 2953.jpg
# 2953.jpg converted to YOLO format
# Resized and saved 2954.jpg
# 2954.jpg converted to YOLO format
# Resized and saved 2955.jpg
# 2955.jpg converted to YOLO format
# Resized and saved 2956.jpg
# 2956.jpg converted to YOLO format
# Resized and saved 2957.jpg
# 2957.jpg converted to YOLO format
# Resized and saved 2958.jpg
# 2958.jpg converted to YOLO format
# Resized and saved 2959.jpg
# 2959.jpg converted to YOLO format
# Resized and saved 2960.jpg
# 2960.jpg converted to YOLO format
# Resized and saved 2961.jpg
# 2961.jpg converted to YOLO format
# Resized and saved 2962.jpg
# 2962.jpg converted to YOLO format
# Resized and saved 2963.jpg
# 2963.jpg converted to YOLO format
# Resized and saved 2964.jpg
# 2964.jpg converted to YOLO format
# Resized and saved 2965.jpg
# 2965.jpg converted to YOLO format
# Resized and saved 2966.jpg
# 2966.jpg converted to YOLO format
# Resized and saved 2967.jpg
# 2967.jpg converted to YOLO format
# Resized and saved 2968.jpg
# 2968.jpg converted to YOLO format
# Resized and saved 2969.jpg
# 2969.jpg converted to YOLO format
# Resized and saved 2970.jpg
# 2970.jpg converted to YOLO format
# Resized and saved 2971.jpg
# 2971.jpg converted to YOLO format
# Resized and saved 2972.jpg
# 2972.jpg converted to YOLO format
# Resized and saved 2973.jpg
# 2973.jpg converted to YOLO format
# Resized and saved 2974.jpg
# 2974.jpg converted to YOLO format
# Resized and saved 2975.jpg
# 2975.jpg converted to YOLO format
# Resized and saved 2976.jpg
# 2976.jpg converted to YOLO format
# Resized and saved 2977.jpg
# 2977.jpg converted to YOLO format
# Resized and saved 2978.jpg
# 2978.jpg converted to YOLO format
# Resized and saved 2979.jpg
# 2979.jpg converted to YOLO format
# Resized and saved 2980.jpg
# 2980.jpg converted to YOLO format
# Resized and saved 2981.jpg
# 2981.jpg converted to YOLO format
# Resized and saved 2982.jpg
# 2982.jpg converted to YOLO format
# Resized and saved 2983.jpg
# 2983.jpg converted to YOLO format
# Resized and saved 2984.jpg
# 2984.jpg converted to YOLO format
# Resized and saved 2985.jpg
# 2985.jpg converted to YOLO format
# Resized and saved 2986.jpg
# 2986.jpg converted to YOLO format
# Resized and saved 2987.jpg
# 2987.jpg converted to YOLO format
# Resized and saved 2988.jpg
# 2988.jpg converted to YOLO format
# Resized and saved 2989.jpg
# 2989.jpg converted to YOLO format
# Resized and saved 2990.jpg
# 2990.jpg converted to YOLO format
# Resized and saved 2991.jpg
# 2991.jpg converted to YOLO format
# Resized and saved 2992.jpg
# 2992.jpg converted to YOLO format
# Resized and saved 2993.jpg
# 2993.jpg converted to YOLO format
# Resized and saved 2994.jpg
# 2994.jpg converted to YOLO format
# Resized and saved 2995.jpg
# 2995.jpg converted to YOLO format
# Resized and saved 2996.jpg
# 2996.jpg converted to YOLO format
# Resized and saved 2997.jpg
# 2997.jpg converted to YOLO format
# Resized and saved 2998.jpg
# 2998.jpg converted to YOLO format
# Resized and saved 2999.jpg
# 2999.jpg converted to YOLO format
# Resized and saved 3000.jpg
# 3000.jpg converted to YOLO format
# Resized and saved 3001.jpg
# 3001.jpg converted to YOLO format
# Resized and saved 3002.jpg
# 3002.jpg converted to YOLO format
# Resized and saved 3003.jpg
# 3003.jpg converted to YOLO format
# Resized and saved 3004.jpg
# 3004.jpg converted to YOLO format
# Resized and saved 3005.jpg
# 3005.jpg converted to YOLO format
# Resized and saved 3006.jpg
# 3006.jpg converted to YOLO format
# Resized and saved 3007.jpg
# 3007.jpg converted to YOLO format
# Resized and saved 3008.jpg
# 3008.jpg converted to YOLO format
# Resized and saved 3009.jpg
# 3009.jpg converted to YOLO format
# Resized and saved 3010.jpg
# 3010.jpg converted to YOLO format
# Resized and saved 3011.jpg
# 3011.jpg converted to YOLO format
# Resized and saved 3012.jpg
# 3012.jpg converted to YOLO format
# Resized and saved 3013.jpg
# 3013.jpg converted to YOLO format
# Resized and saved 3014.jpg
# 3014.jpg converted to YOLO format
# Resized and saved 3015.jpg
# 3015.jpg converted to YOLO format
# Resized and saved 3016.jpg
# 3016.jpg converted to YOLO format
# Resized and saved 3017.jpg
# 3017.jpg converted to YOLO format
# Resized and saved 3018.jpg
# 3018.jpg converted to YOLO format
# Resized and saved 3019.jpg
# 3019.jpg converted to YOLO format
# Resized and saved 3020.jpg
# 3020.jpg converted to YOLO format
# Resized and saved 3021.jpg
# 3021.jpg converted to YOLO format
# Resized and saved 3022.jpg
# 3022.jpg converted to YOLO format
# Resized and saved 3023.jpg
# 3023.jpg converted to YOLO format
# Resized and saved 3024.jpg
# 3024.jpg converted to YOLO format
# Resized and saved 3025.jpg
# 3025.jpg converted to YOLO format
# Resized and saved 3026.jpg
# 3026.jpg converted to YOLO format
# Resized and saved 3027.jpg
# 3027.jpg converted to YOLO format
# Resized and saved 3028.jpg
# 3028.jpg converted to YOLO format
# Resized and saved 3029.jpg
# 3029.jpg converted to YOLO format
# Resized and saved 3030.jpg
# 3030.jpg converted to YOLO format
# Resized and saved 3031.jpg
# 3031.jpg converted to YOLO format
# Resized and saved 3032.jpg
# 3032.jpg converted to YOLO format
# Resized and saved 3033.jpg
# 3033.jpg converted to YOLO format
# Resized and saved 3034.jpg
# 3034.jpg converted to YOLO format
# Resized and saved 3035.jpg
# 3035.jpg converted to YOLO format
# Resized and saved 3036.jpg
# 3036.jpg converted to YOLO format
# Resized and saved 3037.jpg
# 3037.jpg converted to YOLO format
# Resized and saved 3038.jpg
# 3038.jpg converted to YOLO format
# Resized and saved 3039.jpg
# 3039.jpg converted to YOLO format
# Resized and saved 3040.jpg
# 3040.jpg converted to YOLO format
# Resized and saved 3041.jpg
# 3041.jpg converted to YOLO format
# Resized and saved 3042.jpg
# 3042.jpg converted to YOLO format
# Resized and saved 3043.jpg
# 3043.jpg converted to YOLO format
# Resized and saved 3044.jpg
# 3044.jpg converted to YOLO format
# Resized and saved 3045.jpg
# 3045.jpg converted to YOLO format
# Resized and saved 3046.jpg
# 3046.jpg converted to YOLO format
# Resized and saved 3047.jpg
# 3047.jpg converted to YOLO format
# Resized and saved 3048.jpg
# 3048.jpg converted to YOLO format
# Resized and saved 3049.jpg
# 3049.jpg converted to YOLO format
# Resized and saved 3050.jpg
# 3050.jpg converted to YOLO format
# Resized and saved 3051.jpg
# 3051.jpg converted to YOLO format
# Resized and saved 3052.jpg
# 3052.jpg converted to YOLO format
# Resized and saved 3053.jpg
# 3053.jpg converted to YOLO format
# Resized and saved 3054.jpg
# 3054.jpg converted to YOLO format
# Resized and saved 3055.jpg
# 3055.jpg converted to YOLO format
# Resized and saved 3056.jpg
# 3056.jpg converted to YOLO format
# Resized and saved 3057.jpg
# 3057.jpg converted to YOLO format
# Resized and saved 3058.jpg
# 3058.jpg converted to YOLO format
# Resized and saved 3059.jpg
# 3059.jpg converted to YOLO format
# Resized and saved 3060.jpg
# 3060.jpg converted to YOLO format
# Resized and saved 3061.jpg
# 3061.jpg converted to YOLO format
# Resized and saved 3062.jpg
# 3062.jpg converted to YOLO format
# Resized and saved 3063.jpg
# 3063.jpg converted to YOLO format
# Resized and saved 3064.jpg
# 3064.jpg converted to YOLO format
# Resized and saved 3065.jpg
# 3065.jpg converted to YOLO format
# Resized and saved 3066.jpg
# 3066.jpg converted to YOLO format
# Resized and saved 3067.jpg
# 3067.jpg converted to YOLO format
# Resized and saved 3068.jpg
# 3068.jpg converted to YOLO format
# Resized and saved 3069.jpg
# 3069.jpg converted to YOLO format
# Resized and saved 3070.jpg
# 3070.jpg converted to YOLO format
# Resized and saved 3071.jpg
# 3071.jpg converted to YOLO format
# Resized and saved 3072.jpg
# 3072.jpg converted to YOLO format
# Resized and saved 3073.jpg
# 3073.jpg converted to YOLO format
# Resized and saved 3074.jpg
# 3074.jpg converted to YOLO format
# Resized and saved 3075.jpg
# 3075.jpg converted to YOLO format
# Resized and saved 3076.jpg
# 3076.jpg converted to YOLO format
# Resized and saved 3077.jpg
# 3077.jpg converted to YOLO format
# Resized and saved 3078.jpg
# 3078.jpg converted to YOLO format
# Resized and saved 3079.jpg
# 3079.jpg converted to YOLO format
# Resized and saved 3080.jpg
# 3080.jpg converted to YOLO format
# Resized and saved 3081.jpg
# 3081.jpg converted to YOLO format
# Resized and saved 3082.jpg
# 3082.jpg converted to YOLO format
# Resized and saved 3083.jpg
# 3083.jpg converted to YOLO format
# Resized and saved 3084.jpg
# 3084.jpg converted to YOLO format
# Resized and saved 3085.jpg
# 3085.jpg converted to YOLO format
# Resized and saved 3086.jpg
# 3086.jpg converted to YOLO format
# Resized and saved 3087.jpg
# 3087.jpg converted to YOLO format
# Resized and saved 3088.jpg
# 3088.jpg converted to YOLO format
# Resized and saved 3089.jpg
# 3089.jpg converted to YOLO format
# Error processing 3090.jpg: cannot convert float NaN to integer
# Total number of successfully resized and converted images: 3090

# %%
# Check if yolo conversion was successful

# Function to draw bounding boxes on the image
def draw_bboxes(img, bboxes):
    h, w, _ = img.shape
    for bbox in bboxes:
        _, x_center, y_center, bbox_width, bbox_height = bbox

        # Convert YOLO format to bounding box coordinates
        x1 = int((x_center - bbox_width / 2) * w)
        y1 = int((y_center - bbox_height / 2) * h)
        x2 = int((x_center + bbox_width / 2) * w)
        y2 = int((y_center + bbox_height / 2) * h)

        # Draw rectangle without label
        cv2.rectangle(img, (x1, y1), (x2, y2), (0, 255, 0), 1)

    return img

# Function to read YOLO annotation files
def read_yolo_file(yolo_file):
    with open(yolo_file, 'r') as file:
        lines = file.readlines()
        bboxes = []
        for line in lines:
            class_id, x_center, y_center, width, height = map(float, line.strip().split())
            bboxes.append((int(class_id), x_center, y_center, width, height))
    return bboxes

# Directory containing the images and annotation files
image_dir = 'Oxford/Images_resized'
yolo_dir = 'Oxford/Yolo_annotations'

# Process each image
for image_name in os.listdir(image_dir)[:10]:
    if image_name.endswith(('.jpg', '.png')):
        img_path = os.path.join(image_dir, image_name)
        yolo_file = os.path.join(yolo_dir, image_name.replace('.jpg', '.txt').replace('.png', '.txt'))

        # Read image and annotations
        img = cv2.imread(img_path)
        bboxes = read_yolo_file(yolo_file)

        # Draw bounding boxes on the image
        img_with_bboxes = draw_bboxes(img, bboxes)

        # Display the image
        plt.figure(figsize=(5, 5))
        plt.imshow(cv2.cvtColor(img_with_bboxes, cv2.COLOR_BGR2RGB))
        plt.axis('off')
        plt.show()

# %% [markdown]
# ### Resize, filter and download COCO images

# %%
def filter_image_ids(img_dir, coco, coco_caps, words=None):
    # Initialize the Porter Stemmer
    stemmer = PorterStemmer()
    if words:
        stemmed_words = [stemmer.stem(word) for word in words]
    else:
        stemmed_words = []

    # List downloaded images
    downloaded_imgs = set(os.listdir(img_dir))

    # Get image IDs for images containing people
    cat_ids = coco.getCatIds(catNms=['person'])
    img_ids = coco.getImgIds(catIds=cat_ids)

    filtered_img_ids = []
    for img_id in img_ids:
        img_info = coco.loadImgs(img_id)[0]
        img_filename = img_info['file_name']
        if img_filename in downloaded_imgs:
            ann_ids = coco.getAnnIds(imgIds=img_id, iscrowd=None)
            anns = coco.loadAnns(ann_ids)
            if any(ann['bbox'] for ann in anns):
                if stemmed_words:
                    cap_ids = coco_caps.getAnnIds(imgIds=img_id)
                    caps = coco_caps.loadAnns(cap_ids)
                    for cap in caps:
                        caption = cap['caption'].lower()
                        caption_tokens = word_tokenize(caption)
                        stemmed_caption_tokens = [stemmer.stem(token) for token in caption_tokens]
                        if any(stemmed_word in stemmed_caption_tokens for stemmed_word in stemmed_words):
                            filtered_img_ids.append(img_id)
                            break
                else:
                    filtered_img_ids.append(img_id)

    print(f"Found {len(filtered_img_ids)} images matching criteria.")
    return filtered_img_ids


def resize_with_padding(image, target_size):
    # Resize while maintaining aspect ratio
    image.thumbnail((target_size, target_size), Image.LANCZOS)
    # Create a new image with the target size and paste the resized image
    new_image = Image.new("RGB", (target_size, target_size), (0, 0, 0))
    new_image.paste(image, ((target_size - image.width) // 2, (target_size - image.height) // 2))
    return new_image

def download_and_resize_images(img_ids, coco, target_dir, target_size):
    if not os.path.exists(target_dir):
        os.makedirs(target_dir)

    for img_id in img_ids:
        img_info = coco.loadImgs(img_id)[0]
        img_url = img_info['coco_url']
        img_filename = img_info['file_name']
        img_path = os.path.join(target_dir, img_filename)

        if not os.path.exists(img_path):
            response = requests.get(img_url)
            image = Image.open(BytesIO(response.content))

            # Resize image
            resized_image = resize_with_padding(image, target_size)
            resized_image.save(img_path)

            print(f"Downloaded and resized {img_filename}")
        else:
            print(f"{img_filename} already exists.")

# %%
# Download either filtered or unfiltered images to test with what kind of data the models perform better

# Paths to annotation files
coco_train_inst_ann_file = "/content/drive/MyDrive/COCO_dataset/train/raw/instances_train2017.json"
coco_train_caps_ann_file = "/content/drive/MyDrive/COCO_dataset/train/raw/captions_train2017.json"
coco_val_inst_ann_file = "/content/drive/MyDrive/COCO_dataset/validation/raw/instances_val2017.json"
coco_val_caps_ann_file = "/content/drive/MyDrive/COCO_dataset/validation/raw/captions_val2017.json"

# Directory paths (in Colab working directory)
train_img_dir = '/content/drive/MyDrive/COCO_dataset/train/train/data'
val_img_dir = '/content/drive/MyDrive/COCO_dataset/validation/validation/data'
unfiltered_train_img_dir = '/content/drive/MyDrive/COCO_dataset/train/train/imgs'
unfiltered_val_img_dir = '/content/drive/MyDrive/COCO_dataset/validation/validation/imgs'
filtered_train_img_dir = '/content/drive/MyDrive/COCO_dataset/train/train/imgs_filtered'
filtered_val_img_dir = '/content/drive/MyDrive/COCO_dataset/validation/validation/imgs_filtered'

# Words to filter in captions
words = ['street', 'road', 'city', 'surveillance', 'people', 'pedestrian', 'cctv', 'town', 'crosswalk', 'walking', 'group', 'restaurant', 'bike', 'shop',
        'plaza', 'square', 'sidewalk', 'junction', 'avenue', 'boulevard', 'pathway', 'alley', 'intersection']

# Initialize COCO objects
coco_train = COCO(coco_train_inst_ann_file)
coco_train_caps = COCO(coco_train_caps_ann_file)
coco_val = COCO(coco_val_inst_ann_file)
coco_val_caps = COCO(coco_val_caps_ann_file)

# All image IDs
# all_train_img_ids = filter_image_ids(train_img_dir, coco_train, coco_train_caps)
# all_val_img_ids = filter_image_ids(val_img_dir, coco_val, coco_val_caps, words)

# Filter image IDs
train_img_ids = filter_image_ids(train_img_dir, coco_train, coco_train_caps, words)
val_img_ids = filter_image_ids(val_img_dir, coco_val, coco_val_caps, words)

# Download unfiltered images
target_size = 128  # Set the target size for resizing
# download_and_resize_images(all_train_img_ids, coco_train, unfiltered_train_img_dir, target_size)
# download_and_resize_images(all_val_img_ids, coco_val, unfiltered_val_img_dir, target_size)

# Download and resize filtered images
download_and_resize_images(train_img_ids, coco_train, filtered_train_img_dir, target_size)
download_and_resize_images(val_img_ids, coco_val, filtered_val_img_dir, target_size)
